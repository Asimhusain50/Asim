# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/asim/Downloads/ai_ghibli_trend_dataset_v2.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   image_id               500 non-null    object
#  1   user_id                500 non-null    object
#  2   prompt                 500 non-null    object
#  3   likes                  500 non-null    int64
#  4   shares                 500 non-null    int64
#  5   comments               500 non-null    int64
#  6   platform               500 non-null    object
#  7   generation_time        500 non-null    float64
#  8   gpu_usage              500 non-null    int64
#  9   file_size_kb           500 non-null    int64
#  10  resolution             500 non-null    object
#  11  style_accuracy_score   500 non-null    int64
#  12  is_hand_edited         500 non-null    object
#  13  ethical_concerns_flag  500 non-null    object
# ...

# %%
df
# Out:
#                                  image_id   user_id  \
# 0    77ce5c72-eb45-4651-bcb1-c0677c0fceaf  6a7adf3d
# 1    7d66c67f-0d11-4ef9-895c-d865ef11fe40  523b8706
# 2    d7978afd-3932-4cce-9a21-5f9bf2bc1f64  0e02592a
# 3    cb34636a-a15c-4b15-999c-759dbb8896fe  9ed78a42
# 4    7511fbb8-db05-4584-a3a4-e8bb525ed58b  69ec8f02
# ..                                    ...       ...
# 495  135267ba-3941-42ae-a421-3be20e3856d1  c80e6866
# 496  b2ced831-5b08-403d-bfb3-b562e256f359  81669630
# 497  8c87b8aa-b304-43cf-82b3-3a199367ec17  258613ea
# 498  04dba0f4-fdb7-4341-8bb6-dca5a595cd81  23b56439
# 499  1960cd2d-0e99-4e09-b426-62212dd8b37f  7dea460a
#
#                                                 prompt  likes  shares  \
# 0         Studio Ghibli-inspired ocean with giant fish    916     410
# 1                       Ghibli-style village at sunset   2965    1361
# 2          A lone traveler exploring an enchanted ruin   4727     655
# ...

# %%
df.drop('file_size_kb', axis = 1 ,inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   image_id               500 non-null    object
#  1   user_id                500 non-null    object
#  2   prompt                 500 non-null    object
#  3   likes                  500 non-null    int64
#  4   shares                 500 non-null    int64
#  5   comments               500 non-null    int64
#  6   platform               500 non-null    object
#  7   generation_time        500 non-null    float64
#  8   gpu_usage              500 non-null    int64
#  9   resolution             500 non-null    object
#  10  style_accuracy_score   500 non-null    int64
#  11  is_hand_edited         500 non-null    object
#  12  ethical_concerns_flag  500 non-null    object
#  13  creation_date          500 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# image_id                 0
# user_id                  0
# prompt                   0
# likes                    0
# shares                   0
# comments                 0
# platform                 0
# generation_time          0
# gpu_usage                0
# resolution               0
# style_accuracy_score     0
# is_hand_edited           0
# ethical_concerns_flag    0
# creation_date            0
# top_comment              0
# dtype: int64

# %%
df.dtypes
# Out:
# image_id                  object
# user_id                   object
# prompt                    object
# likes                      int64
# shares                     int64
# comments                   int64
# platform                  object
# generation_time          float64
# gpu_usage                  int64
# resolution                object
# style_accuracy_score       int64
# is_hand_edited            object
# ethical_concerns_flag     object
# creation_date             object
# top_comment               object
# dtype: object

# %%
df['generation_time'].mean()
# Out:
# 8.317779999999999

# %%
a = df.groupby('is_hand_edited')['style_accuracy_score'].sum()

# %%
df
# Out:
#                                  image_id   user_id  \
# 0    77ce5c72-eb45-4651-bcb1-c0677c0fceaf  6a7adf3d
# 1    7d66c67f-0d11-4ef9-895c-d865ef11fe40  523b8706
# 2    d7978afd-3932-4cce-9a21-5f9bf2bc1f64  0e02592a
# 3    cb34636a-a15c-4b15-999c-759dbb8896fe  9ed78a42
# 4    7511fbb8-db05-4584-a3a4-e8bb525ed58b  69ec8f02
# ..                                    ...       ...
# 495  135267ba-3941-42ae-a421-3be20e3856d1  c80e6866
# 496  b2ced831-5b08-403d-bfb3-b562e256f359  81669630
# 497  8c87b8aa-b304-43cf-82b3-3a199367ec17  258613ea
# 498  04dba0f4-fdb7-4341-8bb6-dca5a595cd81  23b56439
# 499  1960cd2d-0e99-4e09-b426-62212dd8b37f  7dea460a
#
#                                                 prompt  likes  shares  \
# 0         Studio Ghibli-inspired ocean with giant fish    916     410
# 1                       Ghibli-style village at sunset   2965    1361
# 2          A lone traveler exploring an enchanted ruin   4727     655
# ...

# %%
b = df.groupby('style_accuracy_score')['generation_time'].mean()

# %%
b
# Out:
# style_accuracy_score
# 50      9.651000
# 51      8.724286
# 52      9.233333
# 53      9.650909
# 54      8.571429
# 55     10.182727
# 56      9.300000
# 57      6.940000
# 58      8.280000
# 59      8.730000
# 60      7.828889
# 61      8.295556
# 62      5.958000
# 63      7.540000
# 64      8.935000
# 65      8.222000
# 66      9.110000
# 67      9.993846
# 68      6.383333
# 69     11.191667
# 70      7.999333
# 71     10.415714
# 72      8.419231
# 73      8.244000
# 74     10.518000
# 75      8.447500
# 76      7.696000
# 77      5.082500
# 78      8.993333
# 79      8.496667
# 80      5.977000
# 81      7.288182
# 82      7.153000
# 83      9.598571
# 84      7.043333
# 85      9.542857
# 86      9.664444
# 87      6.840000
# 88      8.840000
# 89      7.625000
# 90      8.988889
# 91      5.785000
# 92      7.212857
# 93      7.674444
# 94      9.283125
# 95      7.080000
# 96      7.778333
# 97      6.783333
# 98      6.881111
# 99     10.375455
# 100     7.095556
# ...

# %%
plt.figure(figsize=(10,8))
sns.barplot (data = df , x = 'platform' , y = 'likes' ,color = 'lightblue')
# Out:
# <Axes: xlabel='platform', ylabel='likes'>

# %%
sns.countplot(data = df , x = 'is_hand_edited')
# Out:
# <Axes: xlabel='is_hand_edited', ylabel='count'>

# %%
plt.figure(figsize = (10,6))
sns.scatterplot(data = df , x = 'generation_time' , y = 'style_accuracy_score' , hue = 'is_hand_edited' , color = 'coolwarm')
plt.xlabel('GENERATION TIME')
plt.ylabel('STYLE ACCURACY SCORE')
plt.title('RELATION BETWEEN GENERATION TIME AND ACCURACY SCORE AND IF ITS HAND EDITED')
plt.tight_layout()
plt.show()

# %%
sns.countplot(data = df, x = 'ethical_concerns_flag')
# Out:
# <Axes: xlabel='ethical_concerns_flag', ylabel='count'>

# %%
df
# Out:
#                                  image_id   user_id  \
# 0    77ce5c72-eb45-4651-bcb1-c0677c0fceaf  6a7adf3d
# 1    7d66c67f-0d11-4ef9-895c-d865ef11fe40  523b8706
# 2    d7978afd-3932-4cce-9a21-5f9bf2bc1f64  0e02592a
# 3    cb34636a-a15c-4b15-999c-759dbb8896fe  9ed78a42
# 4    7511fbb8-db05-4584-a3a4-e8bb525ed58b  69ec8f02
# ..                                    ...       ...
# 495  135267ba-3941-42ae-a421-3be20e3856d1  c80e6866
# 496  b2ced831-5b08-403d-bfb3-b562e256f359  81669630
# 497  8c87b8aa-b304-43cf-82b3-3a199367ec17  258613ea
# 498  04dba0f4-fdb7-4341-8bb6-dca5a595cd81  23b56439
# 499  1960cd2d-0e99-4e09-b426-62212dd8b37f  7dea460a
#
#                                                 prompt  likes  shares  \
# 0         Studio Ghibli-inspired ocean with giant fish    916     410
# 1                       Ghibli-style village at sunset   2965    1361
# 2          A lone traveler exploring an enchanted ruin   4727     655
# ...

# %%
sns.barplot(data=df , x = 'platform' , y = 'shares' , color = 'lightblue',errorbar = None)
# Out:
# <Axes: xlabel='platform', ylabel='shares'>

# %%
corr_matrix = df.corr(numeric_only=True)
sns.heatmap(corr_matrix , annot = True , cmap = 'coolwarm' , fmt = '.2f' , linewidths = 0.5)
# Out:
# <Axes: >

# %%
hand_edited_counts = df['is_hand_edited'].value_counts()

plt.figure(figsize=(6, 6))
plt.pie(hand_edited_counts, labels=hand_edited_counts.index, autopct='%1.1f%%', startangle=90, colors=['blue','red'])
plt.title('Distribution of Hand Edited vs Non-Hand Edited')
plt.axis('equal')  # Ensures pie is a circle
plt.show()

# %%
max_score_index = df['style_accuracy_score'].idxmax()
max_score_row = df.loc[max_score_index]

# %%
max_score_index
max_score_row
# Out:
# image_id                             248d5ac4-5519-4077-b99b-1cdcaf6e96a3
# user_id                                                          4953085a
# prompt                          Ghibli-style night sky with glowing stars
# likes                                                                3133
# shares                                                                695
# comments                                                              843
# platform                                                           TikTok
# generation_time                                                      3.99
# gpu_usage                                                              39
# resolution                                                        512x512
# style_accuracy_score                                                  100
# is_hand_edited                                                         No
# ethical_concerns_flag                                                  No
# ...

# %%
prompt = max_score_row.get('prompt')

# %%
prompt
# Out:
# 'Ghibli-style night sky with glowing stars'

# %%
max_likes_index = df['likes'].idxmax()
max_likes_row = df.loc[max_likes_index]

# %%
max_likes_row
# Out:
# image_id                        ae0e0a6e-3710-4f26-aad7-ee398dc1efe9
# user_id                                                     6de38855
# prompt                   Ghibli-style mountain with floating islands
# likes                                                           4944
# shares                                                          1480
# comments                                                         625
# platform                                                      TikTok
# generation_time                                                 3.47
# gpu_usage                                                         46
# resolution                                                 2048x2048
# style_accuracy_score                                              97
# is_hand_edited                                                   Yes
# ethical_concerns_flag                                            Yes
# creation_date                                             2025-03-19
# ...

# %%
likes_prompt = max_likes_row.get('prompt')

# %%
likes_prompt
# Out:
# 'Ghibli-style mountain with floating islands'

# %%
df
# Out:
#                                  image_id   user_id  \
# 0    77ce5c72-eb45-4651-bcb1-c0677c0fceaf  6a7adf3d
# 1    7d66c67f-0d11-4ef9-895c-d865ef11fe40  523b8706
# 2    d7978afd-3932-4cce-9a21-5f9bf2bc1f64  0e02592a
# 3    cb34636a-a15c-4b15-999c-759dbb8896fe  9ed78a42
# 4    7511fbb8-db05-4584-a3a4-e8bb525ed58b  69ec8f02
# ..                                    ...       ...
# 495  135267ba-3941-42ae-a421-3be20e3856d1  c80e6866
# 496  b2ced831-5b08-403d-bfb3-b562e256f359  81669630
# 497  8c87b8aa-b304-43cf-82b3-3a199367ec17  258613ea
# 498  04dba0f4-fdb7-4341-8bb6-dca5a595cd81  23b56439
# 499  1960cd2d-0e99-4e09-b426-62212dd8b37f  7dea460a
#
#                                                 prompt  likes  shares  \
# 0         Studio Ghibli-inspired ocean with giant fish    916     410
# 1                       Ghibli-style village at sunset   2965    1361
# 2          A lone traveler exploring an enchanted ruin   4727     655
# ...

# %%
ethical_counts = df['ethical_concerns_flag'].value_counts()
plt.figure(figsize = (10,6))
plt.pie(ethical_counts , labels = ethical_counts.index , autopct = '%1.1f%%' , colors = ['blue','red'] , startangle = 90)
plt.axis('equal')
plt.title("ethical concern flags or not")
plt.show()

# %%
df.shape
# Out:
# (500, 15)

# %%
df.
