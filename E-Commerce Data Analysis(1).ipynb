# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer , CountVectorizer

# %%
df = pd.read_csv("/Users/asim/Downloads/Ecommerce_Delivery_Analytics.csv")

# %%
df
# Out:
#         Order ID Customer ID Platform Order Date & Time  \
# 0      ORD000001    CUST2824  JioMart           19:29.5
# 1      ORD000002    CUST1409  Blinkit           54:29.5
# 2      ORD000003    CUST5506  JioMart           21:29.5
# 3      ORD000004    CUST5012  JioMart           19:29.5
# 4      ORD000005    CUST4657  Blinkit           49:29.5
# ...          ...         ...      ...               ...
# 99995  ORD099996    CUST5324  JioMart           49:29.5
# 99996  ORD099997    CUST1677  JioMart           18:29.5
# 99997  ORD099998    CUST8198  JioMart           27:29.5
# 99998  ORD099999    CUST9975  JioMart           14:29.5
# 99999  ORD100000    CUST3748  JioMart           41:29.5
#
#        Delivery Time (Minutes)     Product Category  Order Value (INR)  \
# 0                           30  Fruits & Vegetables                382
# 1                           16                Dairy                279
# 2                           25            Beverages                599
# 3                           42            Beverages                946
# 4                           30            Beverages                334
# ...                        ...                  ...                ...
# 99995                       24                Dairy                289
# 99996                       19               Snacks                322
# 99997                       41                Dairy                135
# 99998                       31              Grocery                973
# 99999                       34  Fruits & Vegetables                453
#
#                    Customer Feedback  Service Rating Delivery Delay  \
# 0      Fast delivery, great service!               5             No
# 1                Quick and reliable!               5             No
# 2          Items missing from order.               2             No
# 3          Items missing from order.               2            Yes
# 4      Fast delivery, great service!               5             No
# ...                              ...             ...            ...
# 99995     Packaging could be better.               3             No
# 99996         Good quality products.               4             No
# 99997  Fast delivery, great service!               5            Yes
# 99998            Quick and reliable!               5             No
# 99999     Packaging could be better.               3             No
#
#       Refund Requested
# 0                   No
# 1                   No
# 2                  Yes
# 3                  Yes
# 4                   No
# ...                ...
# 99995               No
# 99996               No
# 99997               No
# 99998               No
# 99999               No
#
# [100000 rows x 11 columns]

# %%
 #Convert order time into a proper datetime format (assuming missing date)
df['Order Date & Time'] = pd.to_datetime(df['Order Date & Time'],format = "%M:%S.%f")

# %%
# convert order to which order done in which month
df['order_months'] = pd.to_datetime(df['Order Date & Time']).dt.month

# %%
# convert order to which order done in which day 
# day_name shows oders done in which week
df['order_days'] = pd.to_datetime(df['Order Date & Time']).dt.day
df['order_days_name'] = df['Order Date & Time'].dt.day_name()

# %%
# convert order to which order done in which hour
df['order_hour'] = pd.to_datetime(df['Order Date & Time']).dt.hour

# %%
# extract iso calender 
df['order_per_week'] = df['Order Date & Time'].dt.isocalendar().week

# %%
df
# Out:
#         Order ID Customer ID Platform       Order Date & Time  \
# 0      ORD000001    CUST2824  JioMart 1900-01-01 00:19:29.500
# 1      ORD000002    CUST1409  Blinkit 1900-01-01 00:54:29.500
# 2      ORD000003    CUST5506  JioMart 1900-01-01 00:21:29.500
# 3      ORD000004    CUST5012  JioMart 1900-01-01 00:19:29.500
# 4      ORD000005    CUST4657  Blinkit 1900-01-01 00:49:29.500
# ...          ...         ...      ...                     ...
# 99995  ORD099996    CUST5324  JioMart 1900-01-01 00:49:29.500
# 99996  ORD099997    CUST1677  JioMart 1900-01-01 00:18:29.500
# 99997  ORD099998    CUST8198  JioMart 1900-01-01 00:27:29.500
# 99998  ORD099999    CUST9975  JioMart 1900-01-01 00:14:29.500
# 99999  ORD100000    CUST3748  JioMart 1900-01-01 00:41:29.500
#
#        Delivery Time (Minutes)     Product Category  Order Value (INR)  \
# 0                           30  Fruits & Vegetables                382
# 1                           16                Dairy                279
# 2                           25            Beverages                599
# 3                           42            Beverages                946
# 4                           30            Beverages                334
# ...                        ...                  ...                ...
# 99995                       24                Dairy                289
# 99996                       19               Snacks                322
# 99997                       41                Dairy                135
# 99998                       31              Grocery                973
# 99999                       34  Fruits & Vegetables                453
#
#                    Customer Feedback  Service Rating Delivery Delay  \
# 0      Fast delivery, great service!               5             No
# 1                Quick and reliable!               5             No
# 2          Items missing from order.               2             No
# 3          Items missing from order.               2            Yes
# 4      Fast delivery, great service!               5             No
# ...                              ...             ...            ...
# 99995     Packaging could be better.               3             No
# 99996         Good quality products.               4             No
# 99997  Fast delivery, great service!               5            Yes
# 99998            Quick and reliable!               5             No
# 99999     Packaging could be better.               3             No
#
#       Refund Requested  order_months  order_days order_days_name  order_hour  \
# 0                   No             1           1          Monday           0
# 1                   No             1           1          Monday           0
# 2                  Yes             1           1          Monday           0
# 3                  Yes             1           1          Monday           0
# 4                   No             1           1          Monday           0
# ...                ...           ...         ...             ...         ...
# 99995               No             1           1          Monday           0
# 99996               No             1           1          Monday           0
# 99997               No             1           1          Monday           0
# 99998               No             1           1          Monday           0
# 99999               No             1           1          Monday           0
#
#        order_per_week
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   1
# ...               ...
# 99995               1
# 99996               1
# 99997               1
# 99998               1
# 99999               1
#
# [100000 rows x 16 columns]

# %%
#shows which platform has the highest count 
df['Platform'].value_counts()
# Out:
# Platform
# Swiggy Instamart    33449
# Blinkit             33424
# JioMart             33127
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                    Order Date & Time  Delivery Time (Minutes)  \
# count                         100000            100000.000000
# mean   1900-01-01 00:30:02.460999424                29.536140
# min       1900-01-01 00:00:29.500000                 5.000000
# 25%       1900-01-01 00:15:29.500000                23.000000
# 50%       1900-01-01 00:30:29.500000                30.000000
# 75%       1900-01-01 00:45:29.500000                36.000000
# max       1900-01-01 00:59:29.500000                76.000000
# std                              NaN                 9.958933
#
#        Order Value (INR)  Service Rating  order_months  order_days  \
# count      100000.000000   100000.000000      100000.0    100000.0
# mean          590.994400        3.240790           1.0         1.0
# min            50.000000        1.000000           1.0         1.0
# 25%           283.000000        2.000000           1.0         1.0
# 50%           481.000000        3.000000           1.0         1.0
# 75%           770.000000        5.000000           1.0         1.0
# max          2000.000000        5.000000           1.0         1.0
# std           417.409058        1.575962           0.0         0.0
#
#        order_hour  order_per_week
# count    100000.0        100000.0
# mean          0.0             1.0
# min           0.0             1.0
# 25%           0.0             1.0
# 50%           0.0             1.0
# 75%           0.0             1.0
# max           0.0             1.0
# std           0.0             0.0

# %%
# shows if there is any null values
df.isnull().sum()
# Out:
# Order ID                   0
# Customer ID                0
# Platform                   0
# Order Date & Time          0
# Delivery Time (Minutes)    0
# Product Category           0
# Order Value (INR)          0
# Customer Feedback          0
# Service Rating             0
# Delivery Delay             0
# Refund Requested           0
# order_months               0
# order_days                 0
# order_days_name            0
# order_hour                 0
# order_per_week             0
# dtype: int64

# %%
# shows relation between Platform ,  customer feedback and service rating
a = df.groupby(['Customer Feedback','Platform','Service Rating']).size().sort_values(ascending = False)
a
# Out:
# Customer Feedback                           Platform          Service Rating
# Wrong item delivered.                       Blinkit           1                 2638
# Good quality products.                      Blinkit           4                 2634
# Very satisfied with the service.            Swiggy Instamart  5                 2626
# Easy to order, loved it!                    Swiggy Instamart  5                 2622
# Items missing from order.                   JioMart           2                 2611
# Excellent experience!                       JioMart           5                 2608
#                                             Swiggy Instamart  5                 2606
# Packaging could be better.                  Blinkit           3                 2599
# Not fresh, disappointed.                    Blinkit           2                 2596
# Easy to order, loved it!                    JioMart           5                 2596
# Fast delivery, great service!               JioMart           5                 2591
# Packaging could be better.                  Swiggy Instamart  3                 2591
# Horrible experience, never ordering again.  Swiggy Instamart  1                 2590
# Items missing from order.                   Swiggy Instamart  2                 2588
# Good quality products.                      Swiggy Instamart  4                 2584
# Easy to order, loved it!                    Blinkit           5                 2573
# Good quality products.                      JioMart           4                 2571
# Excellent experience!                       Blinkit           5                 2570
# Quick and reliable!                         Blinkit           5                 2569
# Very satisfied with the service.            Blinkit           5                 2568
# Fast delivery, great service!               Swiggy Instamart  5                 2566
# Quick and reliable!                         Swiggy Instamart  5                 2566
# Wrong item delivered.                       JioMart           1                 2564
# Fast delivery, great service!               Blinkit           5                 2558
# Delivery person was rude.                   Swiggy Instamart  2                 2557
#                                             Blinkit           2                 2553
# Very satisfied with the service.            JioMart           5                 2546
# Items missing from order.                   Blinkit           2                 2538
# Very late delivery, not happy.              Swiggy Instamart  2                 2536
# Wrong item delivered.                       Swiggy Instamart  1                 2536
# Delivery person was rude.                   JioMart           2                 2533
# Very late delivery, not happy.              JioMart           2                 2531
#                                             Blinkit           2                 2525
# Quick and reliable!                         JioMart           5                 2523
# Packaging could be better.                  JioMart           3                 2514
# Not fresh, disappointed.                    JioMart           2                 2503
# Horrible experience, never ordering again.  Blinkit           1                 2503
# Not fresh, disappointed.                    Swiggy Instamart  2                 2481
# Horrible experience, never ordering again.  JioMart           1                 2436
# dtype: int64

# %%
# shows customer feedback in barplot
a.plot(kind = 'bar' , color = 'red')
# Out:
# <Axes: xlabel='Customer Feedback,Platform,Service Rating'>

# %%
# shows relation between Platform ,  customer feedback and service rating top 10
a = df.groupby(['Customer Feedback','Platform','Service Rating']).size().sort_values(ascending = False).head(10)
a
# Out:
# Customer Feedback                 Platform          Service Rating
# Wrong item delivered.             Blinkit           1                 2638
# Good quality products.            Blinkit           4                 2634
# Very satisfied with the service.  Swiggy Instamart  5                 2626
# Easy to order, loved it!          Swiggy Instamart  5                 2622
# Items missing from order.         JioMart           2                 2611
# Excellent experience!             JioMart           5                 2608
#                                   Swiggy Instamart  5                 2606
# Packaging could be better.        Blinkit           3                 2599
# Not fresh, disappointed.          Blinkit           2                 2596
# Easy to order, loved it!          JioMart           5                 2596
# dtype: int64

# %%
# shows customer feedback which are top 10
a.plot(kind = 'bar' , color = 'red')
# Out:
# <Axes: xlabel='Customer Feedback,Platform,Service Rating'>

# %%
# shows relation between platform , delivery time , customer feedback and service rating
b = df.groupby(['Platform' , 'Delivery Time (Minutes)' , 'Customer Feedback' , 'Service Rating' , 'Delivery Delay']).size().reset_index(name='count').sort_values(by = 'count',ascending = False)
b
# Out:
#               Platform  Delivery Time (Minutes)  \
# 334            Blinkit                       30
# 333            Blinkit                       30
# 337            Blinkit                       30
# 1823  Swiggy Instamart                       30
# 1082           JioMart                       30
# ...                ...                      ...
# 730            Blinkit                       63
# 729            Blinkit                       63
# 728            Blinkit                       62
# 727            Blinkit                       62
# 2241  Swiggy Instamart                       69
#
#                                Customer Feedback  Service Rating  \
# 334                          Quick and reliable!               5
# 333                   Packaging could be better.               3
# 337                        Wrong item delivered.               1
# 1823                    Easy to order, loved it!               5
# 1082            Very satisfied with the service.               5
# ...                                          ...             ...
# 730   Horrible experience, never ordering again.               1
# 729                     Easy to order, loved it!               5
# 728             Very satisfied with the service.               5
# 727               Very late delivery, not happy.               2
# 2241                         Quick and reliable!               5
#
#      Delivery Delay  count
# 334              No    140
# 333              No    126
# 337              No    125
# 1823             No    124
# 1082             No    123
# ...             ...    ...
# 730             Yes      1
# 729             Yes      1
# 728             Yes      1
# 727             Yes      1
# 2241            Yes      1
#
# [2242 rows x 6 columns]

# %%
# shows barplot between the given data count means how many times customer feedback was reliable according to service rating and delivery delay
# some delivery time is more than 40 so it shows the average of it 
plt.figure(figsize=(10,6))
sns.barplot ( data = b , x = 'Platform' , y = 'Delivery Time (Minutes)' , hue = 'Customer Feedback', palette = 'Set1')
plt.legend(loc ='upper left',bbox_to_anchor=(1.05, 1), borderaxespad=0.)
plt.tight_layout()

# %%
c = df.groupby(['Platform' , 'Product Category' , 'Order Value (INR)']).size().sort_values(ascending = False).reset_index()
c
# Out:
#                Platform Product Category  Order Value (INR)   0
# 0               JioMart           Snacks                237  24
# 1               Blinkit           Snacks                415  24
# 2               JioMart           Snacks                290  23
# 3               Blinkit           Snacks                167  23
# 4               Blinkit           Snacks                439  23
# ...                 ...              ...                ...  ..
# 17324  Swiggy Instamart    Personal Care                999   1
# 17325           Blinkit    Personal Care               1761   1
# 17326           Blinkit    Personal Care               1758   1
# 17327           Blinkit    Personal Care               1755   1
# 17328           Blinkit          Grocery                855   1
#
# [17329 rows x 4 columns]

# %%
# shows the data in barplot in which which product category is ordered from which platform and how much was the Order Value
sns.barplot(data = c , x = 'Platform' , y = 'Order Value (INR)', hue  = 'Product Category',errorbar = None)
# Out:
# <Axes: xlabel='Platform', ylabel='Order Value (INR)'>

# %%
d = df.groupby(['Product Category','Delivery Delay','Refund Requested'])['Delivery Time (Minutes)'].mean().sort_values(ascending = False).reset_index()
d
# Out:
#        Product Category Delivery Delay Refund Requested  \
# 0             Beverages            Yes               No
# 1   Fruits & Vegetables            Yes              Yes
# 2                 Dairy            Yes               No
# 3   Fruits & Vegetables            Yes               No
# 4                Snacks            Yes              Yes
# 5                Snacks            Yes               No
# 6         Personal Care            Yes              Yes
# 7               Grocery            Yes              Yes
# 8               Grocery            Yes               No
# 9                 Dairy            Yes              Yes
# 10        Personal Care            Yes               No
# 11            Beverages            Yes              Yes
# 12            Beverages             No               No
# 13        Personal Care             No               No
# 14  Fruits & Vegetables             No              Yes
# 15        Personal Care             No              Yes
# 16                Dairy             No              Yes
# 17              Grocery             No              Yes
# 18              Grocery             No               No
# 19                Dairy             No               No
# 20               Snacks             No              Yes
# 21  Fruits & Vegetables             No               No
# 22               Snacks             No               No
# 23            Beverages             No              Yes
#
#     Delivery Time (Minutes)
# 0                 45.818031
# 1                 45.815764
# 2                 45.703763
# 3                 45.691188
# 4                 45.533582
# 5                 45.528870
# 6                 45.503408
# 7                 45.502841
# 8                 45.475736
# 9                 45.382879
# 10                45.378973
# 11                45.296008
# 12                27.132425
# 13                27.081397
# 14                27.057539
# 15                27.050539
# 16                27.049487
# 17                27.030496
# 18                27.029209
# 19                26.991790
# 20                26.990288
# 21                26.885759
# 22                26.868947
# 23                26.820301

# %%
# refund requested if theres a delay in delivery
sns.scatterplot(data=d, x='Delivery Delay', y='Product Category', hue='Refund Requested',  palette="viridis")
# Out:
# <Axes: xlabel='Delivery Delay', ylabel='Product Category'>

# %%
# total revenue generated by platform where total orders values came from product category
e = df.groupby(['Platform','Product Category',])['Order Value (INR)'].sum().sort_values(ascending=False).reset_index()
e
# Out:
#             Platform     Product Category  Order Value (INR)
# 0   Swiggy Instamart        Personal Care            5918191
# 1            Blinkit        Personal Care            5741039
# 2            JioMart        Personal Care            5736371
# 3            JioMart              Grocery            4746467
# 4            Blinkit              Grocery            4731502
# 5   Swiggy Instamart              Grocery            4716086
# 6            Blinkit            Beverages            3063913
# 7   Swiggy Instamart            Beverages            3055655
# 8            JioMart            Beverages            2967101
# 9            Blinkit                Dairy            2547605
# 10  Swiggy Instamart                Dairy            2545982
# 11           JioMart                Dairy            2516935
# 12           Blinkit  Fruits & Vegetables            2097912
# 13           JioMart  Fruits & Vegetables            2075237
# 14  Swiggy Instamart  Fruits & Vegetables            2073368
# 15           Blinkit               Snacks            1523113
# 16  Swiggy Instamart               Snacks            1522702
# 17           JioMart               Snacks            1520261

# %%
plt.figure(figsize=(10,8))
sns.barplot(data = e , x = 'Product Category' , y = 'Order Value (INR)' , hue = 'Platform', palette = 'Set1')
plt.xlabel('Product Category')
plt.ylabel('Order Value (INR)')
plt.tight_layout()
plt.show
